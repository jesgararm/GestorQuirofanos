# %% [markdown]
# # Modelo de K-Nearest Neightbors para la predicción de la duración de los quirófanos (versión clasificación)
#  ## Análisis del rendimiento del modelo KNN.
#
#  ### Trabajo de Fin de Grado - Universidad de Burgos
#  #### Jesús García Armario

# %%
from knnClas import KNNClas
import sys
sys.path.append('..\\')
import Utils.common as common

# %%
data = common.FileToDataframe('../../Datos/Listados_Preprocesados/ListadoInterv_Preprocesado_Codificado.xlsx')
data = common.etiquetarDatos(data)
X,Y = common.divideData(data)

# %%
model = KNNClas(X,Y)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
print(model.classification_report())
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      0.72      0.66      1121
#            1       0.45      0.62      0.52      1744
#            2       0.37      0.31      0.33      1151
#            3       0.24      0.06      0.10       511
#            4       0.08      0.01      0.02       207
#            5       0.40      0.30      0.34       365
#
#     accuracy                           0.47      5099
#    macro avg       0.36      0.34      0.33      5099
# weighted avg       0.43      0.47      0.43      5099

# %%
# Mostramos los mejores parámetros
print(model.best_params)
# Out:
# {'algorithm': 'auto', 'leaf_size': 10, 'metric': 'minkowski', 'metric_params': None, 'n_jobs': None, 'n_neighbors': 11, 'p': 1, 'weights': 'uniform'}

# %%
# Mostramos la matriz de confusión
confusion_matrix = model.confusion_matrix()
# Representamos la matriz de confusión
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(confusion_matrix, annot=True, fmt='d')
plt.title('Confusion matrix')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

# %%
# Exportamos el modelo a un fichero
import joblib
joblib.dump(model, 'KNNClas.pkl')
# Out:
# ['KNNClas.pkl']

# %%
# Importamos el modelo de plástica desde un fichero
# Importamos el modelo ampliado
data = common.FileToDataframe('../../Datos/Listados_Preprocesados/ListadoInterv_Preprocesado_PLASTICA_Codificado.xlsx')
data = common.etiquetarDatos(data)
X, Y = common.divideDataAmpli(data)
# Out:
# C:\Users\Jesus\OneDrive\Ingeniería\Cuarto\TFG\GestorQuirofanos\Modelos\Nearest Neightbors\..\Utils\common.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Código diagnóstico'] = data['Código diagnóstico'].astype(float)

# %%
model = KNNClas(X,Y)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
print(model.classification_report())
# Out:
#               precision    recall  f1-score   support
#
#            0       0.51      0.75      0.61       118
#            1       0.41      0.30      0.35       105
#            2       0.34      0.31      0.33        48
#            3       0.00      0.00      0.00        17
#            4       0.00      0.00      0.00         8
#            5       0.00      0.00      0.00         5
#
#     accuracy                           0.45       301
#    macro avg       0.21      0.23      0.21       301
# weighted avg       0.40      0.45      0.41       301
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Mostramos los mejores parámetros
print(model.best_params)
# Out:
# {'algorithm': 'auto', 'leaf_size': 10, 'metric': 'minkowski', 'metric_params': None, 'n_jobs': None, 'n_neighbors': 11, 'p': 2, 'weights': 'uniform'}

# %%
# Mostramos la matriz de confusión
confusion_matrix = model.confusion_matrix()
# Representamos la matriz de confusión
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(confusion_matrix, annot=True, fmt='d')
plt.title('Confusion matrix')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

# %%
# Exportamos el modelo a un fichero
import joblib
joblib.dump(model, 'KNNClas_PLASTICA.pkl')
# Out:
# ['KNNClas_PLASTICA.pkl']
